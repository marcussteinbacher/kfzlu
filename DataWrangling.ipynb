# %%
import pandas as pd

# %%
df = pd.read_excel("../cyl_raw.xlsx")
df
# Out:
#       Drehzahl  Kurbelwinkel  P_ZYL1  P_ZYL2  P_ZYL3  Drehmoment  \
# 0         1600          -360   1.043   1.040   1.014        89.6
# 1         1600          -359   1.048   1.037   1.011        89.6
# 2         1600          -358   1.053   1.045   1.024        89.6
# 3         1600          -357   1.061   1.054   1.028        89.6
# 4         1600          -356   1.067   1.055   1.033        89.6
# ...        ...           ...     ...     ...     ...         ...
# 3595      4600           355   1.380   1.164   1.153        31.1
# 3596      4600           356   1.360   1.163   1.151        31.1
# 3597      4600           357   1.356   1.143   1.147        31.1
# 3598      4600           358   1.343   1.136   1.145        31.1
# 3599      4600           359   1.329   1.114   1.129        31.1
#
#       Absolutverbrauch  Angesaugte Luftmasse  O2 roh  CO roh  ...    Lambda  \
# 0                 3.82               54.6789   0.807  0.7100  ...  0.999158
# ...

# %%
df.loc[:,"ZZP"] = -df["ZZP"]
df
# Out:
#       Drehzahl  Kurbelwinkel  P_ZYL1  P_ZYL2  P_ZYL3  Drehmoment  \
# 0         1600          -360   1.043   1.040   1.014        89.6
# 1         1600          -359   1.048   1.037   1.011        89.6
# 2         1600          -358   1.053   1.045   1.024        89.6
# 3         1600          -357   1.061   1.054   1.028        89.6
# 4         1600          -356   1.067   1.055   1.033        89.6
# ...        ...           ...     ...     ...     ...         ...
# 3595      4600           355   1.380   1.164   1.153        31.1
# 3596      4600           356   1.360   1.163   1.151        31.1
# 3597      4600           357   1.356   1.143   1.147        31.1
# 3598      4600           358   1.343   1.136   1.145        31.1
# 3599      4600           359   1.329   1.114   1.129        31.1
#
#       Absolutverbrauch  Angesaugte Luftmasse  O2 roh  CO roh  ...    Lambda  \
# 0                 3.82               54.6789   0.807  0.7100  ...  0.999158
# ...

# %%
#df.to_csv("cyl_raw.csv",index=False)
